# %%
# Install dependencies if needed (run in a terminal if not in notebook)
# !python -m pip install -r requirements.txt

# %%
# Run training (this will create 'ngen_checkpoint.pth')
# !python train_ngen.py --epochs 10 --lr 1e-3 --save ngen_checkpoint.pth

# %%
# Run evaluation using the saved checkpoint
# !python eval_ngen.py --checkpoint ngen_checkpoint.pth

# %% [markdown]
# After running the above cells, check `final_spread_scatter.png` and `eval_metrics.json` for evaluation results.
# You can also inspect `pheme_synthetic/` for per-thread predictions produced by the model during evaluation run.
